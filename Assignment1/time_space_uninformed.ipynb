# %%
import numpy as np
import pickle
from memory_profiler import memory_usage
import time
import heapq
import math
import tracemalloc
import time
import gc
import csv

# %%
# General Notes:
# - Update the provided file name (code_<RollNumber>.py) as per the instructions.
# - Do not change the function name, number of parameters or the sequence of parameters.
# - The expected output for each function is a path (list of node names)
# - Ensure that the returned path includes both the start node and the goal node, in the correct order.
# - If no valid path exists between the start and goal nodes, the function should return None.

#intializing global variables
global path_exists
path_exists = None


class Node:
    def __init__(self, state, h_score=0, parent=None, depth=0, path_cost=0, x=0, y=0, f_score=0):
        self.state = state
        self.parent = parent
        self.depth = depth
        self.path_cost = path_cost

        # Used only in case of A* algorithms
        self.x = x
        self.y = y
        self.h_score = h_score
        self.f_score = f_score

    def expand(self, adj_matrix, rev=False):
        # Expands a node and allocates memory for each child node
        children = []
        node = self.state
        for child, cost in enumerate(adj_matrix[node]):
            if cost != 0:
                children.append(Node(child, parent=self, depth=self.depth + 1, path_cost=self.path_cost + cost))
        if rev:
            children.reverse()
        return children


    def __lt__(self, other):
        # Used in the A* algorithm, for inserting the nodes in a priority queue based on heuristic
        return self.f_score < other.f_score





def floyd_warshall(adj_matrix):
    n = len(adj_matrix)

    # Initialize a matrix for path existence (True if path exists, False otherwise)
    path_matrix = np.array(adj_matrix, dtype=bool)

    # Floyd-Warshall algorithm
    for k in range(n):
        for i in range(n):
            for j in range(n):
                path_matrix[i][j] = path_matrix[i][j] or (path_matrix[i][k] and path_matrix[k][j])

    return path_matrix


def in_cycle(node):
    ancestor_node = node.parent
    while ancestor_node is not None:
        if node.state == ancestor_node.state:
            return True
        ancestor_node = ancestor_node.parent
    return False

def find_path(node):
    path = []
    while node is not None:
        path.append(node.state)
        node = node.parent
    path.reverse()
    return path

def dfs(adj_matrix, start_node, goal_node, depth):
    frontier = [Node(start_node)]
    cutoff_occurred = False

    while frontier:
        node = frontier.pop()

        if node.state == goal_node:
            return node

        if node.depth > depth:
            cutoff_occurred = True
        else:
            for child in node.expand(adj_matrix, rev=True):
                if not in_cycle(child):
                    frontier.append(child)

    return 'cutoff' if cutoff_occurred else None

def get_ids_path(adj_matrix, start_node, goal_node):
    if not path_exists[start_node][goal_node]:
        return None

    depth = 0
    max_depth = len(adj_matrix)

    while depth < max_depth:
        result = dfs(adj_matrix, start_node, goal_node, depth)

        if result == 'cutoff':
            depth += 1
        elif result is None:
            return None
        else:
            return find_path(result)

    return None





# Algorithm: Bi-Directional Search

# Input:
#   - adj_matrix: Adjacency matrix representing the graph.
#   - start_node: The starting node in the graph.
#   - goal_node: The target node in the graph.

# Return:
#   - A list of node names representing the path from the start_node to the goal_node.
#   - If no path exists, the function should return None.

# Sample Test Cases:

#   Test Case 1:
#     - Start node: 1, Goal node: 2
#     - Return: [1, 7, 6, 2]

#   Test Case 2:
#     - Start node: 5, Goal node: 12
#     - Return: [5, 97, 98, 12]

#   Test Case 3:
#     - Start node: 12, Goal node: 49
#     - Return: None

#   Test Case 4:
#     - Start node: 4, Goal node: 12
#     - Return: [4, 6, 2, 9, 8, 5, 97, 98, 12]



def join_nodes(node_f, node_b):
    # Finds the path given the forward frontier and backward frontier
    path = []
    while node_f:
        path.append(node_f.state)
        node_f = node_f.parent
    path.reverse()

    # Collect the backward path
    node_b_path = []
    while node_b:
        node_b_path.append(node_b.state)
        node_b = node_b.parent

    # Combine paths
    path.extend(node_b_path)
    return path

def get_bidirectional_search_path(adj_matrix, start_node, goal_node):
    # Initialization
    node_f = Node(start_node)
    node_b = Node(goal_node)
    frontier_f = [node_f]
    frontier_b = [node_b]
    visited_f = {node_f.state: node_f}
    visited_b = {node_b.state: node_b}


    while frontier_f and frontier_b:
        # Forward search
        nf = frontier_f.pop(0)
        if nf.state in visited_b:
            return join_nodes(nf, visited_b[nf.state])

        for child in nf.expand(adj_matrix):
            if child.state not in visited_f:
                visited_f[child.state] = child
                frontier_f.append(child)

        # Backward search
        nb = frontier_b.pop(0)
        if nb.state in visited_f:
            return join_nodes(visited_f[nb.state], nb)

        for child in nb.expand(adj_matrix):
            if child.state not in visited_b:
                visited_b[child.state] = child
                frontier_b.append(child)

    gc.collect()

    return None

# %%
def measure_time_1(algorithm, adj_matrix, start_node, goal_node):

    start_time = time.time()  # Start time
    path = algorithm(adj_matrix, start_node, goal_node)
    end_time = time.time() # End time

    print(f"Algorithm: {algorithm.__name__}")
    print(f"Time taken: {end_time - start_time} seconds")

    return end_time - start_time



def measure_memory_1(algorithm, adj_matrix, start_node, goal_node):

    tracemalloc.start()  # Start tracing memory allocation
    path = algorithm(adj_matrix, start_node, goal_node)
    current_mem, peak_mem = tracemalloc.get_traced_memory()  # Get current memory usage
    tracemalloc.stop()  # Stop tracing memory

    current_mem_mb = current_mem / 10**6  # Convert to MB

    print(f"Algorithm: {algorithm.__name__}")
    print(f"Current memory usage: {current_mem_mb} MB")

    return current_mem_mb

# %%
adj_matrix = np.load('IIIT_Delhi.npy')
with open('IIIT_Delhi.pkl', 'rb') as f:
    node_attributes = pickle.load(f)

global path_exists

path_exists = floyd_warshall(adj_matrix)

# Initialize lists to store metrics for each iteration
ids_times = []
ids_memories = []
bbfs_times = []
bbfs_memories = []

# Initialize total time and memory
ids_time_total = 0
ids_memory_total = 0
bbfs_time_total = 0
bbfs_memory_total = 0

# Iteration counter
iteration = 1

# Loop to measure time and memory for each iteration
for i in range(35):
    for j in range(35):
        print("Iteration: ", iteration)
        
        # Measure time and memory for IDS
        ids_time = measure_time_1(get_ids_path, adj_matrix, i, j)
        ids_memory = measure_memory_1(get_ids_path, adj_matrix, i, j)
        ids_times.append(ids_time)
        ids_memories.append(ids_memory)
        ids_time_total += ids_time
        ids_memory_total += ids_memory
        
        # Measure time and memory for BBFS
        bbfs_time = measure_time_1(get_bidirectional_search_path, adj_matrix, i, j)
        bbfs_memory = measure_memory_1(get_bidirectional_search_path, adj_matrix, i, j)
        bbfs_times.append(bbfs_time)
        bbfs_memories.append(bbfs_memory)
        bbfs_time_total += bbfs_time
        bbfs_memory_total += bbfs_memory

        iteration += 1

# Write the metrics to a CSV file
with open('uninformed_algorithm_performance.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    # Write header
    writer.writerow(['Iteration', 'IDS Time (seconds)', 'IDS Memory (MB)', 'BBFS Time (seconds)', 'BBFS Memory (MB)'])
    
    # Write data for each iteration
    for iter_num in range(len(ids_times)):
        writer.writerow([iter_num + 1, ids_times[iter_num], ids_memories[iter_num], bbfs_times[iter_num], bbfs_memories[iter_num]])

# Print total time and memory for each algorithm
print(f"Total Iterative Deepening Search time: {ids_time_total:.6f} seconds")
print(f"Total Iterative Deepening Search memory: {ids_memory_total:.6f} MB")
print(f"Total Bidirectional Heuristic Time: {bbfs_time_total:.6f} seconds")
print(f"Total Bidirectional Heuristic memory: {bbfs_memory_total:.6f} MB")
# Out:
# Iteration:  1
# Algorithm: get_ids_path
# Time taken: 9.298324584960938e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 5.758186 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 3.743171691894531e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  2
# Algorithm: get_ids_path
# Time taken: 6.4373016357421875e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04767560958862305 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  3
# Algorithm: get_ids_path
# Time taken: 9.059906005859375e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.043955087661743164 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  4
# Algorithm: get_ids_path
# Time taken: 1.4543533325195312e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.048751115798950195 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001463 MB
# Iteration:  5
# Algorithm: get_ids_path
# Time taken: 2.1219253540039062e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.048673391342163086 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001161 MB
# Iteration:  6
# Algorithm: get_ids_path
# Time taken: 1.2159347534179688e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04796338081359863 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  7
# Algorithm: get_ids_path
# Time taken: 1.2636184692382812e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0449674129486084 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.005675 MB
# Iteration:  8
# Algorithm: get_ids_path
# Time taken: 1.1444091796875e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.044579267501831055 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  9
# Algorithm: get_ids_path
# Time taken: 8.344650268554688e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.041320085525512695 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  10
# Algorithm: get_ids_path
# Time taken: 7.867813110351562e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04346656799316406 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.00024 MB
# Iteration:  11
# Algorithm: get_ids_path
# Time taken: 1.1444091796875e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04427742958068848 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.0 MB
# Iteration:  12
# Algorithm: get_ids_path
# Time taken: 1.049041748046875e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.042116403579711914 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  13
# Algorithm: get_ids_path
# Time taken: 9.298324584960938e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.042607784271240234 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.005668 MB
# Iteration:  14
# Algorithm: get_ids_path
# Time taken: 1.1205673217773438e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04559612274169922 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.0 MB
# Iteration:  15
# Algorithm: get_ids_path
# Time taken: 1.0013580322265625e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0430912971496582 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  16
# Algorithm: get_ids_path
# Time taken: 8.58306884765625e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04316830635070801 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.005682 MB
# Iteration:  17
# Algorithm: get_ids_path
# Time taken: 1.0728836059570312e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04423403739929199 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001097 MB
# Iteration:  18
# Algorithm: get_ids_path
# Time taken: 1.0013580322265625e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.043076276779174805 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  19
# Algorithm: get_ids_path
# Time taken: 9.775161743164062e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.043309688568115234 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  20
# Algorithm: get_ids_path
# Time taken: 9.298324584960938e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.043402671813964844 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001161 MB
# Iteration:  21
# Algorithm: get_ids_path
# Time taken: 1.0251998901367188e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04248189926147461 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  22
# Algorithm: get_ids_path
# Time taken: 2.8371810913085938e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 1.1444091796875e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  23
# Algorithm: get_ids_path
# Time taken: 0.0002853870391845703 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 9.72747802734375e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  24
# Algorithm: get_ids_path
# Time taken: 0.001546621322631836 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0002810955047607422 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  25
# Algorithm: get_ids_path
# Time taken: 0.000247955322265625 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 8.726119995117188e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  26
# Algorithm: get_ids_path
# Time taken: 0.0007793903350830078 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0002741813659667969 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  27
# Algorithm: get_ids_path
# Time taken: 0.000125885009765625 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 6.508827209472656e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  28
# Algorithm: get_ids_path
# Time taken: 3.4332275390625e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 3.337860107421875e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  29
# Algorithm: get_ids_path
# Time taken: 0.0003228187561035156 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00015544891357421875 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  30
# Algorithm: get_ids_path
# Time taken: 0.00012373924255371094 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00011515617370605469 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  31
# Algorithm: get_ids_path
# Time taken: 0.0031402111053466797 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000216 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0005297660827636719 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  32
# Algorithm: get_ids_path
# Time taken: 0.0004875659942626953 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0002315044403076172 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  33
# Algorithm: get_ids_path
# Time taken: 0.0047686100006103516 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000269 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0005433559417724609 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  34
# Algorithm: get_ids_path
# Time taken: 0.018568992614746094 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.002204 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0013039112091064453 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000786 MB
# Iteration:  35
# Algorithm: get_ids_path
# Time taken: 3.5762786865234375e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04565095901489258 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.0 MB
# Iteration:  36
# Algorithm: get_ids_path
# Time taken: 0.004765510559082031 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0004990100860595703 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  37
# Algorithm: get_ids_path
# Time taken: 2.86102294921875e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04568219184875488 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.006743 MB
# Iteration:  38
# Algorithm: get_ids_path
# Time taken: 0.37793779373168945 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0011 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0022153854370117188 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001154 MB
# Iteration:  39
# Algorithm: get_ids_path
# Time taken: 0.04666543006896973 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000988 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0015077590942382812 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000674 MB
# Iteration:  40
# Algorithm: get_ids_path
# Time taken: 0.045607566833496094 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.00093 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0013802051544189453 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000706 MB
# Iteration:  41
# Algorithm: get_ids_path
# Time taken: 4.0531158447265625e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04185628890991211 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  42
# Algorithm: get_ids_path
# Time taken: 0.00033736228942871094 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00010204315185546875 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  43
# Algorithm: get_ids_path
# Time taken: 7.152557373046875e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 6.9141387939453125e-06 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  44
# Algorithm: get_ids_path
# Time taken: 0.00079345703125 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00025391578674316406 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  45
# Algorithm: get_ids_path
# Time taken: 0.0001010894775390625 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 6.198883056640625e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  46
# Algorithm: get_ids_path
# Time taken: 0.00035834312438964844 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0001461505889892578 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  47
# Algorithm: get_ids_path
# Time taken: 3.62396240234375e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 3.361701965332031e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  48
# Algorithm: get_ids_path
# Time taken: 9.72747802734375e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 5.984306335449219e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  49
# Algorithm: get_ids_path
# Time taken: 0.0001220703125 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00011539459228515625 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  50
# Algorithm: get_ids_path
# Time taken: 3.4332275390625e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 3.409385681152344e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  51
# Algorithm: get_ids_path
# Time taken: 0.0028340816497802734 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0005757808685302734 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  52
# Algorithm: get_ids_path
# Time taken: 4.076957702636719e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 3.528594970703125e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  53
# Algorithm: get_ids_path
# Time taken: 0.0028586387634277344 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0007131099700927734 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  54
# Algorithm: get_ids_path
# Time taken: 0.011890649795532227 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0013585090637207031 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  55
# Algorithm: get_ids_path
# Time taken: 2.6226043701171875e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04947471618652344 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001431 MB
# Iteration:  56
# Algorithm: get_ids_path
# Time taken: 0.003038644790649414 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000993 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00045943260192871094 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  57
# Algorithm: get_ids_path
# Time taken: 2.86102294921875e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0480809211730957 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  58
# Algorithm: get_ids_path
# Time taken: 0.25925540924072266 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.001149 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00223541259765625 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001154 MB
# Iteration:  59
# Algorithm: get_ids_path
# Time taken: 0.029668092727661133 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.001474142074584961 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.00016 MB
# Iteration:  60
# Algorithm: get_ids_path
# Time taken: 0.028768062591552734 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.001036 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.001432180404663086 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000706 MB
# Iteration:  61
# Algorithm: get_ids_path
# Time taken: 4.0531158447265625e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04483747482299805 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  62
# Algorithm: get_ids_path
# Time taken: 0.001116037368774414 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00031375885009765625 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  63
# Algorithm: get_ids_path
# Time taken: 0.0005240440368652344 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0002319812774658203 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  64
# Algorithm: get_ids_path
# Time taken: 6.198883056640625e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 6.4373016357421875e-06 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  65
# Algorithm: get_ids_path
# Time taken: 0.0019888877868652344 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00040650367736816406 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  66
# Algorithm: get_ids_path
# Time taken: 3.910064697265625e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 3.62396240234375e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  67
# Algorithm: get_ids_path
# Time taken: 0.0010137557983398438 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0002970695495605469 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  68
# Algorithm: get_ids_path
# Time taken: 0.0019359588623046875 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0004024505615234375 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  69
# Algorithm: get_ids_path
# Time taken: 0.00010585784912109375 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 6.461143493652344e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  70
# Algorithm: get_ids_path
# Time taken: 0.0002422332763671875 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00014495849609375 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  71
# Algorithm: get_ids_path
# Time taken: 0.0005979537963867188 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00025534629821777344 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  72
# Algorithm: get_ids_path
# Time taken: 0.0003151893615722656 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.000152587890625 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  73
# Algorithm: get_ids_path
# Time taken: 0.0003972053527832031 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0001914501190185547 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  74
# Algorithm: get_ids_path
# Time taken: 0.0015552043914794922 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0003788471221923828 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  75
# Algorithm: get_ids_path
# Time taken: 1.430511474609375e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04309797286987305 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.003228 MB
# Iteration:  76
# Algorithm: get_ids_path
# Time taken: 0.00023293495178222656 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00010180473327636719 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  77
# Algorithm: get_ids_path
# Time taken: 1.6689300537109375e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.044492483139038086 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.0 MB
# Iteration:  78
# Algorithm: get_ids_path
# Time taken: 0.136824369430542 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.00254 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0021791458129882812 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001394 MB
# Iteration:  79
# Algorithm: get_ids_path
# Time taken: 0.015605926513671875 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0015974044799804688 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  80
# Algorithm: get_ids_path
# Time taken: 0.009884834289550781 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0012314319610595703 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  81
# Algorithm: get_ids_path
# Time taken: 4.291534423828125e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04572916030883789 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.005748 MB
# Iteration:  82
# Algorithm: get_ids_path
# Time taken: 0.0006225109100341797 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00021600723266601562 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  83
# Algorithm: get_ids_path
# Time taken: 0.0002143383026123047 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000777 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00016427040100097656 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  84
# Algorithm: get_ids_path
# Time taken: 0.0034515857696533203 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0008378028869628906 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  85
# Algorithm: get_ids_path
# Time taken: 2.0265579223632812e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 1.239776611328125e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  86
# Algorithm: get_ids_path
# Time taken: 0.001619100570678711 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0007064342498779297 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  87
# Algorithm: get_ids_path
# Time taken: 7.867813110351562e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 6.508827209472656e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  88
# Algorithm: get_ids_path
# Time taken: 0.00010561943054199219 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 6.29425048828125e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  89
# Algorithm: get_ids_path
# Time taken: 0.0004353523254394531 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00018143653869628906 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  90
# Algorithm: get_ids_path
# Time taken: 0.0002033710479736328 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 9.226799011230469e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  91
# Algorithm: get_ids_path
# Time taken: 0.004393577575683594 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0005669593811035156 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  92
# Algorithm: get_ids_path
# Time taken: 0.0002052783966064453 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 9.012222290039062e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  93
# Algorithm: get_ids_path
# Time taken: 0.0043871402740478516 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0006892681121826172 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  94
# Algorithm: get_ids_path
# Time taken: 0.01747298240661621 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0010955333709716797 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.00016 MB
# Iteration:  95
# Algorithm: get_ids_path
# Time taken: 8.821487426757812e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04679584503173828 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001527 MB
# Iteration:  96
# Algorithm: get_ids_path
# Time taken: 0.004441499710083008 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.001105 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0005655288696289062 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  97
# Algorithm: get_ids_path
# Time taken: 2.86102294921875e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.046027183532714844 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  98
# Algorithm: get_ids_path
# Time taken: 0.4475274085998535 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.001267 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0019068717956542969 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001218 MB
# Iteration:  99
# Algorithm: get_ids_path
# Time taken: 0.04455757141113281 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.00093 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.004647731781005859 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000674 MB
# Iteration:  100
# Algorithm: get_ids_path
# Time taken: 0.07383322715759277 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.00093 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00157928466796875 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000674 MB
# Iteration:  101
# Algorithm: get_ids_path
# Time taken: 3.814697265625e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.045230865478515625 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  102
# Algorithm: get_ids_path
# Time taken: 0.0008151531219482422 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0003108978271484375 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  103
# Algorithm: get_ids_path
# Time taken: 0.0003209114074707031 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0001544952392578125 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  104
# Algorithm: get_ids_path
# Time taken: 3.600120544433594e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 3.4332275390625e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  105
# Algorithm: get_ids_path
# Time taken: 0.0014159679412841797 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00033211708068847656 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  106
# Algorithm: get_ids_path
# Time taken: 6.4373016357421875e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 5.9604644775390625e-06 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  107
# Algorithm: get_ids_path
# Time taken: 0.0007028579711914062 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00030350685119628906 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  108
# Algorithm: get_ids_path
# Time taken: 0.0014164447784423828 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00032329559326171875 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  109
# Algorithm: get_ids_path
# Time taken: 3.62396240234375e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 3.457069396972656e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  110
# Algorithm: get_ids_path
# Time taken: 0.00011944770812988281 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00011658668518066406 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  111
# Algorithm: get_ids_path
# Time taken: 0.00040340423583984375 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.000171661376953125 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  112
# Algorithm: get_ids_path
# Time taken: 0.0005331039428710938 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0002181529998779297 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  113
# Algorithm: get_ids_path
# Time taken: 0.0004322528839111328 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00019359588623046875 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  114
# Algorithm: get_ids_path
# Time taken: 0.002302885055541992 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0005979537963867188 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  115
# Algorithm: get_ids_path
# Time taken: 1.6689300537109375e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.041021108627319336 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.013971 MB
# Iteration:  116
# Algorithm: get_ids_path
# Time taken: 0.00035881996154785156 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00010371208190917969 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  117
# Algorithm: get_ids_path
# Time taken: 1.9073486328125e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.041838884353637695 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.002824 MB
# Iteration:  118
# Algorithm: get_ids_path
# Time taken: 0.10303640365600586 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.001484 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0021352767944335938 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001122 MB
# Iteration:  119
# Algorithm: get_ids_path
# Time taken: 0.010896921157836914 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0014202594757080078 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  120
# Algorithm: get_ids_path
# Time taken: 0.010718584060668945 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0010745525360107422 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  121
# Algorithm: get_ids_path
# Time taken: 2.1457672119140625e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.040770769119262695 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  122
# Algorithm: get_ids_path
# Time taken: 0.0007023811340332031 seconds
# Algorithm: get_ids_path
# Current memory usage: 9.6e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00011539459228515625 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  123
# Algorithm: get_ids_path
# Time taken: 3.981590270996094e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 3.790855407714844e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  124
# Algorithm: get_ids_path
# Time taken: 0.0012462139129638672 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000192 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0002834796905517578 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  125
# Algorithm: get_ids_path
# Time taken: 4.172325134277344e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 3.838539123535156e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  126
# Algorithm: get_ids_path
# Time taken: 0.001186370849609375 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0002818107604980469 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  127
# Algorithm: get_ids_path
# Time taken: 6.198883056640625e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 5.9604644775390625e-06 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  128
# Algorithm: get_ids_path
# Time taken: 3.910064697265625e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 3.600120544433594e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  129
# Algorithm: get_ids_path
# Time taken: 0.0002741813659667969 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00014400482177734375 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  130
# Algorithm: get_ids_path
# Time taken: 9.560585021972656e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 6.341934204101562e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  131
# Algorithm: get_ids_path
# Time taken: 0.0038633346557617188 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0005652904510498047 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  132
# Algorithm: get_ids_path
# Time taken: 0.00010085105895996094 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 6.461143493652344e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  133
# Algorithm: get_ids_path
# Time taken: 0.003738880157470703 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0006816387176513672 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  134
# Algorithm: get_ids_path
# Time taken: 0.014378070831298828 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0010499954223632812 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  135
# Algorithm: get_ids_path
# Time taken: 1.6689300537109375e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04509592056274414 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.012921 MB
# Iteration:  136
# Algorithm: get_ids_path
# Time taken: 0.0038156509399414062 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.00136 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0005002021789550781 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  137
# Algorithm: get_ids_path
# Time taken: 2.86102294921875e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.044786930084228516 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  138
# Algorithm: get_ids_path
# Time taken: 0.32035279273986816 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.001481 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.001913309097290039 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001154 MB
# Iteration:  139
# Algorithm: get_ids_path
# Time taken: 0.03764796257019043 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0015416145324707031 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  140
# Algorithm: get_ids_path
# Time taken: 0.038430213928222656 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.00065 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0012977123260498047 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.00016 MB
# Iteration:  141
# Algorithm: get_ids_path
# Time taken: 3.337860107421875e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.042127132415771484 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.003228 MB
# Iteration:  142
# Algorithm: get_ids_path
# Time taken: 8.702278137207031e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 4.291534423828125e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  143
# Algorithm: get_ids_path
# Time taken: 0.00012969970703125 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 9.322166442871094e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  144
# Algorithm: get_ids_path
# Time taken: 0.0020101070404052734 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000778 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0004038810729980469 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  145
# Algorithm: get_ids_path
# Time taken: 0.000141143798828125 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 8.988380432128906e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  146
# Algorithm: get_ids_path
# Time taken: 0.0010364055633544922 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0003566741943359375 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  147
# Algorithm: get_ids_path
# Time taken: 3.695487976074219e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 3.361701965332031e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  148
# Algorithm: get_ids_path
# Time taken: 5.245208740234375e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 5.9604644775390625e-06 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  149
# Algorithm: get_ids_path
# Time taken: 0.0004949569702148438 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00017380714416503906 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  150
# Algorithm: get_ids_path
# Time taken: 0.0002040863037109375 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00011420249938964844 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  151
# Algorithm: get_ids_path
# Time taken: 0.0038204193115234375 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0005629062652587891 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  152
# Algorithm: get_ids_path
# Time taken: 0.00028514862060546875 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00011849403381347656 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  153
# Algorithm: get_ids_path
# Time taken: 0.006066799163818359 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0006456375122070312 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  154
# Algorithm: get_ids_path
# Time taken: 0.023392438888549805 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0010366439819335938 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.00016 MB
# Iteration:  155
# Algorithm: get_ids_path
# Time taken: 1.9073486328125e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04302191734313965 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.0001 MB
# Iteration:  156
# Algorithm: get_ids_path
# Time taken: 0.006258249282836914 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000946 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0012204647064208984 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  157
# Algorithm: get_ids_path
# Time taken: 3.5762786865234375e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04660677909851074 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  158
# Algorithm: get_ids_path
# Time taken: 0.5816900730133057 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.001434 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0026235580444335938 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001218 MB
# Iteration:  159
# Algorithm: get_ids_path
# Time taken: 0.05813336372375488 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000875 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0015921592712402344 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000674 MB
# Iteration:  160
# Algorithm: get_ids_path
# Time taken: 0.057801008224487305 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000988 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0013804435729980469 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000674 MB
# Iteration:  161
# Algorithm: get_ids_path
# Time taken: 4.0531158447265625e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.05549263954162598 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  162
# Algorithm: get_ids_path
# Time taken: 0.0009105205535888672 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0003814697265625 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  163
# Algorithm: get_ids_path
# Time taken: 0.0002760887145996094 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0002608299255371094 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  164
# Algorithm: get_ids_path
# Time taken: 0.0002079010009765625 seconds
# ...
# Time taken: 0.0022759437561035156 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001282 MB
# Iteration:  348
# Algorithm: get_ids_path
# Time taken: 0.26144981384277344 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.001069 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.002089262008666992 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001282 MB
# Iteration:  349
# Algorithm: get_ids_path
# Time taken: 0.05266857147216797 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000926 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0022478103637695312 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001314 MB
# Iteration:  350
# Algorithm: get_ids_path
# Time taken: 0.0842292308807373 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000926 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0020198822021484375 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001227 MB
# Iteration:  351
# Algorithm: get_ids_path
# Time taken: 0.015389680862426758 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0012409687042236328 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.00016 MB
# Iteration:  352
# Algorithm: get_ids_path
# Time taken: 0.11454153060913086 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.00099 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.002123594284057617 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001355 MB
# Iteration:  353
# Algorithm: get_ids_path
# Time taken: 0.014294624328613281 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0014064311981201172 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  354
# Algorithm: get_ids_path
# Time taken: 0.18416428565979004 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.001069 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0023450851440429688 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001794 MB
# Iteration:  355
# Algorithm: get_ids_path
# Time taken: 3.814697265625e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04510807991027832 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  356
# Algorithm: get_ids_path
# Time taken: 0.035485267639160156 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.002655 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.002220630645751953 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001522 MB
# Iteration:  357
# Algorithm: get_ids_path
# Time taken: 4.0531158447265625e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0445857048034668 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  358
# Algorithm: get_ids_path
# Time taken: 2.6702880859375e-05 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 1.2159347534179688e-05 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  359
# Algorithm: get_ids_path
# Time taken: 0.001232147216796875 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00034427642822265625 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  360
# Algorithm: get_ids_path
# Time taken: 0.0030961036682128906 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0006337165832519531 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  361
# Algorithm: get_ids_path
# Time taken: 2.6226043701171875e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04100990295410156 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  362
# Algorithm: get_ids_path
# Time taken: 0.07062292098999023 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.002927 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0016262531280517578 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000793 MB
# Iteration:  363
# Algorithm: get_ids_path
# Time taken: 0.037049055099487305 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0014650821685791016 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  364
# Algorithm: get_ids_path
# Time taken: 0.008729696273803711 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000933 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0012712478637695312 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000674 MB
# Iteration:  365
# Algorithm: get_ids_path
# Time taken: 0.0812070369720459 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000871 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0014820098876953125 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000674 MB
# Iteration:  366
# Algorithm: get_ids_path
# Time taken: 0.010303497314453125 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0014417171478271484 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  367
# Algorithm: get_ids_path
# Time taken: 0.05666232109069824 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000933 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0015611648559570312 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000674 MB
# Iteration:  368
# Algorithm: get_ids_path
# Time taken: 0.08949947357177734 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000988 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0016317367553710938 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000674 MB
# Iteration:  369
# Algorithm: get_ids_path
# Time taken: 0.014969110488891602 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0013988018035888672 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  370
# Algorithm: get_ids_path
# Time taken: 0.023785829544067383 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0021638870239257812 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000673 MB
# Iteration:  371
# Algorithm: get_ids_path
# Time taken: 0.003204345703125 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0004725456237792969 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  372
# Algorithm: get_ids_path
# Time taken: 0.03675055503845215 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0014581680297851562 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.00337 MB
# Iteration:  373
# Algorithm: get_ids_path
# Time taken: 0.001699209213256836 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000192 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0004489421844482422 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000224 MB
# Iteration:  374
# Algorithm: get_ids_path
# Time taken: 0.03961443901062012 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0018367767333984375 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000416 MB
# Iteration:  375
# Algorithm: get_ids_path
# Time taken: 3.814697265625e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04561638832092285 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.001431 MB
# Iteration:  376
# Algorithm: get_ids_path
# Time taken: 0.010318279266357422 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0010712146759033203 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  377
# Algorithm: get_ids_path
# Time taken: 3.5762786865234375e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04757499694824219 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  378
# Algorithm: get_ids_path
# Time taken: 0.0012433528900146484 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0003790855407714844 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  379
# Algorithm: get_ids_path
# Time taken: 8.106231689453125e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 6.67572021484375e-06 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  380
# Algorithm: get_ids_path
# Time taken: 0.00013113021850585938 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00012087821960449219 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  381
# Algorithm: get_ids_path
# Time taken: 1.9073486328125e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0452883243560791 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.008438 MB
# Iteration:  382
# Algorithm: get_ids_path
# Time taken: 0.033997535705566406 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000873 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0014536380767822266 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  383
# Algorithm: get_ids_path
# Time taken: 0.020210742950439453 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.002916 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0016338825225830078 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000706 MB
# Iteration:  384
# Algorithm: get_ids_path
# Time taken: 0.004685640335083008 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.001102447509765625 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  385
# Algorithm: get_ids_path
# Time taken: 0.053131103515625 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000875 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0013341903686523438 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000674 MB
# Iteration:  386
# Algorithm: get_ids_path
# Time taken: 0.004373788833618164 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0010061264038085938 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  387
# Algorithm: get_ids_path
# Time taken: 0.03182363510131836 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0012841224670410156 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  388
# Algorithm: get_ids_path
# Time taken: 0.05061030387878418 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.00065 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0028014183044433594 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  389
# Algorithm: get_ids_path
# Time taken: 0.00820612907409668 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000705 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.002435445785522461 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  390
# Algorithm: get_ids_path
# Time taken: 0.016566991806030273 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0012798309326171875 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  391
# Algorithm: get_ids_path
# Time taken: 0.0016205310821533203 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0004227161407470703 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 9.6e-05 MB
# Iteration:  392
# Algorithm: get_ids_path
# Time taken: 0.01931309700012207 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0013692378997802734 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000962 MB
# Iteration:  393
# Algorithm: get_ids_path
# Time taken: 0.0009429454803466797 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0003142356872558594 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000611 MB
# Iteration:  394
# Algorithm: get_ids_path
# Time taken: 0.01951766014099121 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.000128 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0013675689697265625 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.00016 MB
# Iteration:  395
# Algorithm: get_ids_path
# Time taken: 2.384185791015625e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.04254794120788574 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 6.4e-05 MB
# Iteration:  396
# Algorithm: get_ids_path
# Time taken: 0.00434422492980957 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.005572 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0010592937469482422 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  397
# Algorithm: get_ids_path
# Time taken: 3.0994415283203125e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 0.0 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.046889305114746094 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.0 MB
# Iteration:  398
# Algorithm: get_ids_path
# Time taken: 0.0030052661895751953 seconds
# Algorithm: get_ids_path
# Current memory usage: 6.4e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.0006690025329589844 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 0.000128 MB
# Iteration:  399
# Algorithm: get_ids_path
# Time taken: 0.00013875961303710938 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 0.00012087821960449219 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Iteration:  400
# Algorithm: get_ids_path
# Time taken: 5.9604644775390625e-06 seconds
# Algorithm: get_ids_path
# Current memory usage: 3.2e-05 MB
# Algorithm: get_bidirectional_search_path
# Time taken: 5.9604644775390625e-06 seconds
# Algorithm: get_bidirectional_search_path
# Current memory usage: 3.2e-05 MB
# Total Iterative Deepening Search time: 7.114508 seconds
# Total Iterative Deepening Search memory: 5.870540 MB
# Total Bidirectional Heuristic Time: 5.104185 seconds
# Total Bidirectional Heuristic memory: 0.240007 MB
